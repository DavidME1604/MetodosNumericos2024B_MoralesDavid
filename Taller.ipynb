# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(x):
    return x**3 - 3*x**2 + x - 1

# Create an array of x values
x = np.linspace(-2, 4, 400)
y = f(x)

# Plot the function
plt.plot(x, y, label='f(x) = x^3 - 3x^2 + x - 1')
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.title('Plot of the function f(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid()
plt.show()

# %%
from scipy.optimize import newton

x0 = 100

x_r = newton(f, x0)

x_r
# Out:
# 2.7692923542386314

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(x):
    return x**3 - 3*x**2 + x - 1

# Generate x values
x = np.linspace(-5, 5, 400)
y = f(x)

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = x^2 - 4', color='blue')
plt.axhline(0, color='black', lw=0.5, ls='--')
plt.axvline(0, color='black', lw=0.5, ls='--')
plt.scatter(x_r, f(x_r), color='red', zorder=5, label='Roots')
plt.title('Plot of the function and its roots')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid()
plt.ylim(-10, 10)
plt.show()

# %%
def f(x):
    print(f'f({x}) = {x**3 - 3*x**2 + x - 1}')  # Corrected to use x
    return x**3 - 3*x**2 + x - 1

x0 = 100  # Initial guess

# Find the root using Newton's method
x_r = newton(f, x0)

x_r  # This will display the root found
# Out:
# f(100.0) = 970099.0
# f(100.01010000000001) = 970395.9803980006
# f(67.00792386980214) = 287465.54571529943
# f(53.116335372259854) = 141447.59273483977
# f(39.65955343460801) = 57699.74450824955
# f(30.388236067683557) = 25320.914914632634
# f(23.137873990336278) = 10803.174516522931
# f(17.742617932460977) = 4657.725983130829
# f(13.65347387896111) = 1998.6458316465025
# f(10.579948354366646) = 858.043795817009
# f(8.267818948297682) = 367.35922412035336
# f(6.536804537670478) = 156.66380304361124
# f(5.249698727272358) = 66.24990348675587
# f(4.306584492248163) = 27.539375882553202
# f(3.6356358117218313) = 11.037373198988304
# f(3.1868714328556598) = 4.084765647739281
# f(2.923215343365569) = 1.2670760212328207
# f(2.804652849575538) = 0.26803700410227016
# f(2.772843145360331) = 0.02631152581509344
# f(2.7693806975473843) = 0.0006530032799583196
# f(2.769292579076204) = 1.6618166540638413e-06
# f(2.7692923542528955) = 1.0542855477524427e-10
# 2.7692923542386314

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import newton

def f(x: float) -> float:
    return x**3 - 3*x**2 + x - 1

def f_prime(x: float) -> float:
    return 3*x**2 - 6*x + 1

def newton_con_estim(func, x0, func_prime, show=False, tol=1e-7, max_iter=100):
    estimaciones = []
    x = x0
    for i in range(max_iter):
        y = func(x)
        estimaciones.append((x, y))
        if show:
            print(f'Iteración {i}: x = {x}, f(x) = {y}')
        if abs(y) < tol:
            break
        x = x - y / func_prime(x)
    return x, estimaciones

# Initial guess
x0 = 100
raiz, estimaciones = newton_con_estim(f, x0, f_prime, show=True)

# Prepare data for plotting
x_estim, y_estim = zip(*estimaciones)

# Plotting the estimates
plt.plot(x_estim, y_estim, marker='o', color='red', label='Estimaciones de Newton')
plt.axhline(0, color='black', lw=0.5)
plt.xlabel('x')
plt.ylabel('y(x)')
plt.legend()
plt.title("Trayectoria de las estimaciones de las raíces")
plt.grid()
plt.show()

print("\nRaíz encontrada:", raiz)
# Out:
# Iteración 0: x = 100, f(x) = 970099
# Iteración 1: x = 67.00455766810653, f(x) = 287421.5546044976
# Iteración 2: x = 45.009926065596666, f(x) = 85151.64374336696
# Iteración 3: x = 30.35039723527028, f(x) = 25223.076156622286
# Iteración 4: x = 20.582860416480248, f(x) = 7468.634520318185
# Iteración 5: x = 14.079716839009599, f(x) = 2209.5053464848224
# Iteración 6: x = 9.757835905944379, f(x) = 652.2076251031732
# Iteración 7: x = 6.898518561069087, f(x) = 191.4272950525605
# Iteración 8: x = 5.028701696557697, f(x) = 55.330187134373084
# Iteración 9: x = 3.843680657951718, f(x) = 15.30811830079546
# Iteración 10: x = 3.1559707952275144, f(x) = 3.709463570275677
# Iteración 11: x = 2.8454158843448356, f(x) = 0.593842355835478
# Iteración 12: x = 2.773143092634202, f(x) = 0.0285402881796184
# Iteración 13: x = 2.7693029596247096, f(x) = 7.838698133211253e-05
# Iteración 14: x = 2.7692923543194023, f(x) = 5.96992677515118e-10
# Raíz encontrada: 2.7692923543194023

# %%
import numpy as np
import matplotlib.pyplot as plt

# Función objetivo
def f(x):
    return 3*x**2 - 6*x + 1

# Derivada de la función
def fprime(x):
    return 6*x - 6

# Implementación manual del método de Newton con registro de iteraciones
def newton_registro(f, x0, fprime, maxiter):
    estimaciones = [x0]  # Lista para registrar las estimaciones
    for i in range(maxiter):
        # Actualizar la estimación usando la fórmula de Newton-Raphson
        x0 = x0 - f(x0) / fprime(x0)
        estimaciones.append(x0)
    return estimaciones

# Parámetros iniciales
x0 = 100
maxiter = 10

# Obtener las estimaciones
resultados = newton_registro(f, x0, fprime, maxiter)
print("Estimaciones:", resultados)

# Graficar las estimaciones
plt.plot(resultados, 'o-', label="Trayectoria de puntos")
plt.xlabel("Iteración")
plt.ylabel("Estimación de la raíz")
plt.title("Trayectoria de puntos en el método de Newton")
plt.legend()
plt.grid()
plt.show()
# Out:
# Estimaciones: [100, 50.503367003367, 25.75841705039971, 13.39267195998467, 7.223233596132716, 4.165179520433147, 2.6879023755616003, 2.0414349630035384, 1.8407886767034236, 1.81684750496698, 1.816496656307574]
